# %% [markdown]
# loading the dataset

# %%
import pandas as pd 
import numpy as np 

data = pd.read_csv('dataset.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    Time_s  Strain_microstrain  Temperature_C  Bragg_Wavelength_nm  \
# 0       0            0.000000       0.000000          1549.996654
# 1       1            4.999917       0.025000          1550.006398
# 2       2            9.999333       0.049999          1550.013439
# 3       3           14.997750       0.074997          1550.028074
# 4       4           19.994667       0.099993          1550.029701
#
#    Residual_nm  Damage_Label  Damage_Severity
# 0     0.003346             0              0.0
# 1     0.000002             0              0.0
# 2     0.000641             0              0.0
# 3     0.008878             0              0.0
# 4     0.004110             0              0.0
